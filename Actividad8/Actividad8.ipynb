# %% [markdown]
# <a href="https://colab.research.google.com/github/sebasbrowar/FisicaComputacional1/blob/main/Actividad8/Actividad8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # $\text{Actividad 8}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## $\text{Ejercicio 1}$

# %% [markdown]
# Resuelva la ecuación diferencial del [oscilador de Van der Pol](https://en.wikipedia.org/wiki/Van_der_Pol_oscillator)
#
# \begin{equation*}
# \frac{d^2 x}{d t^2} - \mu (1 - x^2) \frac{dx}{dt } + x = 0
# \end{equation*}
#
# donde $x$ es la posición y $\mu$ es un parámetro de la parte no lineal.
#
# Resuelva el caso para $\mu = 0, 1, 2, 3, 4$ y grafique las soluciones para un tiempo de integración de t = [0, 50]

# %% [markdown]
# ### $\mu$ = 0

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt

# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente mu
mu=0.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol=odeint(VanderPol, y_0, t, args=(mu,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('Solución del Oscilador de Van der Pol, mu=0 (odeint)')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\mu$ = 1

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt

# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente mu
mu=1.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol=odeint(VanderPol, y_0, t, args=(mu,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('Solución del Oscilador de Van der Pol, mu=1 (odeint)')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\mu$ = 2

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt

# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente mu
mu=2.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol=odeint(VanderPol, y_0, t, args=(mu,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('Solución del Oscilador de Van der Pol, mu=2 (odeint)')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\mu$ = 3

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt

# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente mu
mu=3.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol=odeint(VanderPol, y_0, t, args=(mu,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('Solución del Oscilador de Van der Pol, mu=3 (odeint)')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\mu$ = 4

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt

# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente mu
mu=4.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol=odeint(VanderPol, y_0, t, args=(mu,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('Solución del Oscilador de Van der Pol, mu=4 (odeint)')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ## $\text{Ejercicio 2}$

# %% [markdown]
# Siguiendo con el ejemplo anterior del [oscilador de Van de Pol](https://en.wikipedia.org/wiki/Van_der_Pol_oscillator), reproduce la gráfica del [plano fase](https://en.wikipedia.org/wiki/Phase_plane) ($\theta, \omega$) que aparece en la Wikipedia para distintos valores de $\mu$ y se reproduce abajo.
#
# ![VanderPol-lc.png](data:image/png;base64,...)

# %%
# Integración utilizando 'odeint'

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def VanderPol(y,t,mu):
        x, v = y
        dydt = [v, mu*(1 - x**2)*v - x]
        return dydt


# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=50.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos los coeficiente mu
mu0=0.01
mu1=0.1
mu2=0.5
mu3=1.0
mu4=1.5
mu5=2.0
mu6=2.5
mu7=3.0
mu8=3.5
mu9=4.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol0 = odeint(VanderPol, y_0, t, args=(mu0,), atol=abserr, rtol=relerr)
sol1 = odeint(VanderPol, y_0, t, args=(mu1,), atol=abserr, rtol=relerr)
sol2 = odeint(VanderPol, y_0, t, args=(mu2,), atol=abserr, rtol=relerr)
sol3 = odeint(VanderPol, y_0, t, args=(mu3,), atol=abserr, rtol=relerr)
sol4 = odeint(VanderPol, y_0, t, args=(mu4,), atol=abserr, rtol=relerr)
sol5 = odeint(VanderPol, y_0, t, args=(mu5,), atol=abserr, rtol=relerr)
sol6 = odeint(VanderPol, y_0, t, args=(mu6,), atol=abserr, rtol=relerr)
sol7 = odeint(VanderPol, y_0, t, args=(mu7,), atol=abserr, rtol=relerr)
sol8 = odeint(VanderPol, y_0, t, args=(mu8,), atol=abserr, rtol=relerr)
sol9 = odeint(VanderPol, y_0, t, args=(mu9,), atol=abserr, rtol=relerr)

plt.plot(sol0[:,0], sol0[:,1], label='mu=0.01')
plt.plot(sol1[:,0], sol1[:,1], label='mu=0.1')
plt.plot(sol2[:,0], sol2[:,1], label='mu=0.5')
plt.plot(sol3[:,0], sol3[:,1], label='mu=1')
plt.plot(sol4[:,0], sol4[:,1], label='mu=1.5')
plt.plot(sol5[:,0], sol5[:,1], label='mu=2')
plt.plot(sol6[:,0], sol6[:,1], label='mu=2.5')
plt.plot(sol7[:,0], sol7[:,1], label='mu=3')
plt.plot(sol8[:,0], sol8[:,1], label='mu=3.5')
plt.plot(sol9[:,0], sol9[:,1], label='mu=4')

plt.legend(loc='lower right')
plt.xlim([-2.5,2.5])
plt.ylim([-8,8])
plt.axes().set_aspect('auto')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ## $\text{Ejercicio 3}$

# %% [markdown]
# Encuentre las soluciones de las siguientes Ecuaciones Diferenciales Ordinarias, utilizando los siguientes métodos:
#
#
# *   Método de Euler
# *   Método de Runge-Kutta RK4
# *   Función *scipy.integrate.odeint* ó *scipy.integrate-solve_ivp*
#
# **Ejercicio 3.1:**
#
# \begin{equation*}
# \frac{d^2 x}{dt^2} + k (\frac{dx}{dt})^2 -g = 0, \ x(0)=0, \ \frac{dx}{dt}(0). = 0, \ k>0.
# \end{equation*}
#
# **Ejercicio 3.2:**
#
# \begin{equation*}
# \frac{d^2 y}{d x^2} + \frac{2}{x} \frac{dy}{dx} + y^5 =0, \ y(0) = 1, \ \frac{dy}{dx}(0)=0.
# \end{equation*}
#
# **Ejercicio 3.3:**
#
# \begin{equation*}
# \frac{d^3 y}{d x^3} = (x-1)^2 + y^2 + \frac{dy}{dx} -2, \ y(0)=1, \ y'(0)=0, \ y''(0)=2.
# \end{equation*}
#
# Grafique las soluciones como funciones del tiempo.

# %% [markdown]
# ### $\text{Ejercicio 3.1}$

# %% [markdown]
# ### $\text{3.1 - Euler}$

# %%
# euler
t = np.linspace(0,2,21)
y0 = 0
x0 = 0
euler31 = lambda y,t: -k*y**2 + g

y = np.zeros(len(t))
y[0] = y0
x = np.zeros(len(t))
x[0] = x0

# y
for n in range(0,len(t)-1):
        y[n+1] = y[n] + euler31(y[n],t[n])*(t[n+1] - t[n])
# x
for n in range(0,len(t)-1):
       x[n+1] = x[n] + y[n]*(t[n+1] - t[n])

plt.figure(figsize=(10,5))
plt.plot(t,y,'b')
plt.plot(t,x,'g')
plt.axis([0,2,0,9])
plt.grid()
plt.title("Método de Euler para 3.1")
plt.legend(['y(t)', 'x(t)'])
plt.xlabel('t')
plt.show()

# %% [markdown]
# ### $\text{3.1 - Runge-Kutta RK4}$

# %%
# Tomada la versión de Joshua Simon
# https://github.com/JoshuaSimon/Classic-Fourth-Order-Runge-Kutta-Method-RK4/blob/master/Four_Step_Runge_Kutta_ODE1.py

"""Four_Step_Runge_Kutta_ODE1.py 

Implementation of the classic fourth-order method also refered as the
"original" Runge–Kutta method. This method is an implicit four step
Runge-Kutta method which solves an intial value problem numerically. 
"""

from datetime import datetime
import matplotlib.pyplot as plt
from math import exp, sqrt 

__date__ = datetime(2019, 6, 6) # or version string or something
__author__ = "Joshua Simon"


def runge_kutta(f, x_0, y_0, h):
    """Four step Runge-Kutta method (RK4)
    Solves first order ODEs
    """
    k_0 = f(x_0, y_0)
    k_1 = f(x_0 + h/2, y_0 + h/2 * k_0)
    k_2 = f(x_0 + h/2, y_0 + h/2 * k_1)
    k_3 = f(x_0 + h, y_0 + h * k_2)

    k = 1/6 * (k_0 + 2.0*k_1 + 2.0*k_2 + k_3)

    x_1 = x_0 + h
    y_1 = y_0 + h * k

    return x_1, y_1

# %%
# Definimos la parte derecha de la ecuación

def f(y,t):
        x, v = y
        dydt = [v, -(v)**2 + g]
        return dydt

# Condiciones iniciales
t_0 = 0.0
y_0 = 0.0
l = 1.0
g = 9.81

# Paso de integración h = (b-a)/Npts
a=0
b=10.0
Npts=100
h = (b-a)/Npts

t_values = [t_0]
y_values = [y_0]

# Calcula la solución con RK4
t = t_0
y = y_0

for _ in range(Npts):
  t, y = runge_kutta(f, t, y, h)
  t_values.append(t)
  y_values.append(y)


# Graficar la solución

plt.figure(figsize=(10,5))
plt.plot(t_values, y_values, 'b', label='y(t)')
plt.legend(loc='best')
plt.title('Solución de la EDO usando Runge-Kutta RK4')
plt.xlabel('t')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5e3c4ae02e76> in <module>()
#      26
#      27 for _ in range(Npts):
# ---> 28   t, y = runge_kutta(f, t, y, h)
#      29   t_values.append(t)
#      30   y_values.append(y)
#
# <ipython-input-4-3d139a30d8b2> in runge_kutta(f, x_0, y_0, h)
#      21     Solves first order ODEs
#      22     """
# ---> 23     k_0 = f(x_0, y_0)
#      24     k_1 = f(x_0 + h/2, y_0 + h/2 * k_0)
#      25     k_2 = f(x_0 + h/2, y_0 + h/2 * k_1)
#
# <ipython-input-14-5e3c4ae02e76> in f(y, t)
#       2
#       3 def f(y,t):
# ----> 4         x, v = y
#       5         dydt = [v, -(v)**2 + g]
#       6         return dydt
#
# TypeError: cannot unpack non-iterable float object

# %% [markdown]
# ### $\text{3.1 - odeint}$

# %%
# Integración utilizando 'odeint' para el 3.1

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def ode31(y,t,k):
        x, v = y
        dydt = [v, -k*(v)**2 + g]
        return dydt


# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=2.0
Npts=600
g = 9.81

# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos el coeficiente k
k = 1.0

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [0.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol = odeint(ode31, y_0, t, args=(k,), atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol[:,0]
y2=sol[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('scipy.integrate.odeint para 3.1')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\text{Ejercicio 3.2}$

# %% [markdown]
# ### $\text{3.2 - Euler}$

# %%
# el metodo de euler da error
t = np.linspace(0,2,21)
v0 = 0
x0 = 0
euler32 = lambda v,t: -(2/x)*v - y**5

v = np.zeros(len(t))
v[0] = v0
x = np.zeros(len(t))
x[0] = x0

# v
for n in range(0,len(t)-1):
        v[n+1] = v[n] + euler32(v[n],t[n])*(t[n+1] - t[n])
# x
for n in range(0,len(t)-1):
       x[n+1] = x[n] + v[n]*(t[n+1] - t[n])

plt.figure(figsize=(10,5))
plt.plot(t,v,'b')
plt.plot(t,x,'g')
plt.axis([0,2,0,9])
plt.grid()
plt.title("Método de Euler para 3.1")
plt.legend(['v(t)', 'x(t)'])
plt.xlabel('t')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-a481ac79a46b> in <module>()
#      12 # v
#      13 for n in range(0,len(t)-1):
# ---> 14         v[n+1] = v[n] + euler32(v[n],t[n])*(t[n+1] - t[n])
#      15 # x
#      16 for n in range(0,len(t)-1):
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# ### $\text{3.2 - odeint}$

# %%
# Integración utilizando 'odeint' para el 3.2

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def ode32(y,t):
        i, v = y
        dydt = [v, -(2/t)*v - i**5]
        return dydt


# Paso de integración h = (tmax-t0)/Npts
t0=0.01
tmax=5.0
Npts=600


# Definimos el tiempo de integración
t = np.linspace(t0,tmax,Npts)

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
y_0 = [1.0, 0.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol2 = odeint(ode32, y_0, t, atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# La solución regresa ambas x(t) y v(t)
y1=sol2[:,0]
y2=sol2[:,1]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.legend(loc='best')
plt.title('scipy.integrate.odeint para 3.2')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ### $\text{Ejercicio 3.3}$

# %% [markdown]
# ### $\text{3.3 - Euler}$

# %%
# Integración utilizando 'odeint' para el 3.3

from scipy.integrate import solve_ivp, odeint

# definimos la función F de lado derecho de la ecuación.
def ode33(a,t):
        y, v, z = a
        dadt = [v, z, (t-1)**2 + y**2 + v - 2]
        return dadt


# Paso de integración h = (tmax-t0)/Npts
t0=0
tmax=5.0
Npts=600

# Definimos el tiempo de integración
t = np.linspace(t0,2,Npts)

# Definimos las condiciones iniciales 
t_0 = 0.0
# y_0 = [x_0, v_0] 
z_0 = [1.0, 0.0, 2.0]

# Definimos los errores de tolerancia para la solución
abserr = 1.0e-8
relerr = 1.0e-6

sol3 = odeint(ode33, z_0, t, atol=abserr, rtol=relerr)
#print(t)
#print(sol[:,0],sol[:,1])

# soluciones
y1=sol3[:,0]
y2=sol3[:,1]
y3=sol3[:,2]

plt.figure(figsize=(10,5))
plt.plot(t, y1, 'b', label='x(t)')
plt.plot(t, y2, 'g', label='v(t)')
plt.plot(t, y3, 'y', label='z(t)')
plt.legend(loc='best')
plt.title('scipy.integrate.odeint para 3.3')
plt.xlabel('t')
plt.grid()
plt.show()
